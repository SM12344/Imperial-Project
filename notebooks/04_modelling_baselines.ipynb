# %% [markdown]
# # 04 Modelling Baselines

# %% [markdown]
# ## 1. Inputs and Outputs

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

def configure_script_path(project_root: Path) -> Path:
    scripts_dir = project_root / "scripts"
    if str(scripts_dir) not in sys.path:
        sys.path.insert(0, str(scripts_dir))
    return scripts_dir

SCRIPTS_DIR = configure_script_path(PROJECT_ROOT)
print(f'Initial project root: {PROJECT_ROOT}')
print(f'Scripts directory: {SCRIPTS_DIR}')

# %%
try:
    from google.colab import drive  # type: ignore
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    drive.mount('/content/drive')
    COLAB_PROJECT_ROOT = Path('/content/drive/Othercomputers/My laptop/Documents/Imperial College/Project')
    PROJECT_ROOT = COLAB_PROJECT_ROOT.resolve()
    SCRIPTS_DIR = configure_script_path(PROJECT_ROOT)
    print(f'Using project root: {PROJECT_ROOT}')
    print(f'Scripts directory: {SCRIPTS_DIR}')
else:
    print('Not running in Colab. Skipping Drive mount.')

# %%
from run_modelling_baselines import FEATURE_SETS, run_pipeline

# %% [markdown]
# ## 2. Baseline Experiments

# %%
outputs = run_pipeline(
    project_root=str(PROJECT_ROOT),
    dataset_name='model_dataset_finbert_complete.csv',
    test_fraction=0.2,
)

results_df = outputs['results_df']
split_df = outputs['split_df']
feature_manifest_df = outputs['feature_manifest_df']
predictions_df = outputs['predictions_df']

results_df

# %% [markdown]
# ## 3. Inspect the Time Split

# %%
split_df

# %% [markdown]
# ## 4. Inspect Feature Sets

# %%
feature_manifest_df

# %% [markdown]
# ## 5. Inspect Test Predictions

# %%
predictions_df.head()
