# %% [markdown]
# # 03 FinBERT Sentiment Pipeline

# %% [markdown]
# ## 1. Inputs and Outputs

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

def configure_script_path(project_root: Path) -> Path:
    scripts_dir = project_root / "scripts"
    if str(scripts_dir) not in sys.path:
        sys.path.insert(0, str(scripts_dir))
    return scripts_dir

SCRIPTS_DIR = configure_script_path(PROJECT_ROOT)
print(f'Initial project root: {PROJECT_ROOT}')
print(f'Scripts directory: {SCRIPTS_DIR}')

# %%
try:
    from google.colab import drive  # type: ignore
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    drive.mount('/content/drive')
    COLAB_PROJECT_ROOT = Path('/content/drive/Othercomputers/My laptop/Documents/Imperial College/Project')
    PROJECT_ROOT = COLAB_PROJECT_ROOT.resolve()
    SCRIPTS_DIR = configure_script_path(PROJECT_ROOT)
    print(f'Using project root: {PROJECT_ROOT}')
    print(f'Scripts directory: {SCRIPTS_DIR}')
else:
    print('Not running in Colab. Skipping Drive mount.')

# %%
from run_finbert_sentiment_pipeline import MODEL_NAME, run_pipeline

# %% [markdown]
# ## 2. FinBERT Pipeline

# %%
outputs = run_pipeline(
    project_root=str(PROJECT_ROOT),
    batch_size=16,
    max_length=512,
    model_name=MODEL_NAME,
    local_files_only=False,
)

summary = outputs["summary"]
article_summary = outputs["article_summary"]
metadata = outputs["metadata"]

summary

# %% [markdown]
# ## 3. Inspect Article-Level Scoring

# %%
article_summary

# %%
outputs["article_scores"].head()

# %% [markdown]
# ## 4. Inspect Daily Ticker-Level Sentiment Features

# %%
outputs["daily_coverage"]

# %%
outputs["daily_finbert"].head()

# %% [markdown]
# ## 5. Inspect Final Model Dataset

# %%
outputs["model_df"].head()

# %%
outputs["complete_model_df"].head()

# %%
metadata
