# %% [markdown]
# # Final Results Summary

# %%
from pathlib import Path
import subprocess
import sys

import pandas as pd
from IPython.display import Image, display

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
TABLES = PROJECT_ROOT / "outputs" / "tables"
FIGURES = PROJECT_ROOT / "outputs" / "figures"

PROJECT_ROOT

# %% [markdown]
# ## Evidence Pack

# %%
subprocess.run(
    [sys.executable, str(PROJECT_ROOT / "scripts" / "build_final_evidence_pack.py"), "--project-root", str(PROJECT_ROOT)],
    check=True,
)

# %%
def read_final(name: str) -> pd.DataFrame:
    return pd.read_csv(TABLES / name)

headline = read_final("final_headline_results.csv")
audit = read_final("final_leakage_and_sanity_audit.csv")
selective = read_final("final_selective_10d_summary.csv")
selective_by_ticker = read_final("final_selective_10d_by_ticker.csv")
pooled_classification = read_final("final_pooled_classification_best_by_horizon.csv")
pooled_regression = read_final("final_pooled_regression_best_by_horizon.csv")
target_formulation = read_final("final_target_formulation_best_all_rows.csv")
feature_deltas = read_final("final_feature_value_deltas.csv")
news_coverage = read_final("final_news_coverage_by_ticker.csv")
finbert_labels = read_final("final_finbert_label_distribution.csv")

# %% [markdown]
# ## Headline Results

# %%
headline

# %%
display(Image(filename=str(FIGURES / "final_headline_results.png")))

# %% [markdown]
# ## Leakage and Sanity Audit

# %%
audit

# %% [markdown]
# ## Selective 10-Day Result

# %%
selective

# %%
selective_by_ticker

# %%
display(Image(filename=str(FIGURES / "final_selective_10d_confusion_matrix.png")))
display(Image(filename=str(FIGURES / "final_selective_10d_by_ticker.png")))

# %% [markdown]
# ## Broad Pooled Models

# %%
pooled_classification

# %%
pooled_regression

# %%
display(Image(filename=str(FIGURES / "final_pooled_classification_by_horizon.png")))

# %% [markdown]
# ## Target Formulation and Feature Engineering

# %%
target_formulation.head(10)

# %%
feature_deltas

# %%
display(Image(filename=str(FIGURES / "final_feature_value_deltas.png")))

# %% [markdown]
# ## Data and Sentiment Coverage

# %%
news_coverage

# %%
finbert_labels

# %%
display(Image(filename=str(FIGURES / "final_news_coverage_by_ticker.png")))
display(Image(filename=str(FIGURES / "final_finbert_label_distribution.png")))
